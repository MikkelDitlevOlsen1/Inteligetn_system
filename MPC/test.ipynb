# %%
from map import *
from map_simulation import *

# %%
import matplotlib.pyplot as plt

# %%
map1=random_map_generater(num_cleaners=4, num_windows=50)
map2=random_map_generater(num_cleaners=2, num_windows=50)

print(len(map1.states))
print(len(map2.states))
# Out:
# 486
# 486
